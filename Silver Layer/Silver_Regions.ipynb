# %%
df=spark.read.table("catabricks_cat.bronze.regions")
df=df.drop('_rescued_data')
display(df)

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@databricksstorageak.dfs.core.windows.net/regions")

# %%
df=spark.read.format("delta").load("abfss://silver@databricksstorageak.dfs.core.windows.net/regions").display()

# %%
df=spark.read.format("delta").load("abfss://silver@databricksstorageak.dfs.core.windows.net/orders").display()

# %%
df=spark.read.format("delta").load("abfss://silver@databricksstorageak.dfs.core.windows.net/customers").display()

# %%
df=spark.read.format("delta").load("abfss://silver@databricksstorageak.dfs.core.windows.net/products").display()

# %%
# %sql
create table if not exists catabricks_cat.silver.regions_silver using delta 
location 'abfss://silver@databricksstorageak.dfs.core.windows.net/regions'
